# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: openai==0.28 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 1)) (0.28.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: graphdatascience in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 2)) (1.11)
# Requirement already satisfied: retry==0.9.2 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 3)) (0.9.2)
# Requirement already satisfied: langchain>=0.0.216 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 4)) (0.3.0)
# Requirement already satisfied: streamlit==1.23.1 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 5)) (1.23.1)
# Requirement already satisfied: streamlit-chat==0.0.2.2 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 6)) (0.0.2.2)
# Requirement already satisfied: streamlit-chat-media==0.0.4 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 7)) (0.0.4)
# Requirement already satisfied: numpy in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 8)) (1.26.4)
# Requirement already satisfied: pandas in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 9)) (2.2.2)
# Requirement already satisfied: plotly==5.15.0 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 10)) (5.15.0)
# Requirement already satisfied: altair<5 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 11)) (4.2.2)
# Requirement already satisfied: python-dotenv==1.0.0 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 12)) (1.0.0)
# Requirement already satisfied: requests>=2.20 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from openai==0.28->-r requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from openai==0.28->-r requirements.txt (line 1)) (4.66.5)
# Requirement already satisfied: aiohttp in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from openai==0.28->-r requirements.txt (line 1)) (3.10.5)
# Requirement already satisfied: decorator>=3.4.2 in c:\users\akshi\appdata\roaming\python\python312\site-packages (from retry==0.9.2->-r requirements.txt (line 3)) (5.1.1)
# Requirement already satisfied: py<2.0.0,>=1.4.26 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from retry==0.9.2->-r requirements.txt (line 3)) (1.11.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (1.8.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (8.1.7)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (6.11.0)
# Requirement already satisfied: packaging<24,>=14.1 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (23.2)
# Requirement already satisfied: pillow<10,>=6.2.0 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (9.5.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (4.25.5)
# Requirement already satisfied: pyarrow>=4.0 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (16.1.0)
# Requirement already satisfied: pympler<2,>=0.9 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (1.1)
# Requirement already satisfied: python-dateutil<3,>=2 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (2.9.0.post0)
# Requirement already satisfied: rich<14,>=10.11.0 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (13.8.1)
# Requirement already satisfied: tenacity<9,>=8.0.0 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (8.5.0)
# Requirement already satisfied: toml<2 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.0.1 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (4.12.2)
# Requirement already satisfied: tzlocal<5,>=1.1 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (4.3.1)
# Requirement already satisfied: validators<1,>=0.2 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (0.34.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.1.dev5 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\akshi\appdata\roaming\python\python312\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (6.4.1)
# Requirement already satisfied: watchdog in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from streamlit==1.23.1->-r requirements.txt (line 5)) (5.0.2)
# Requirement already satisfied: multimethod<2.0,>=1.0 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from graphdatascience->-r requirements.txt (line 2)) (1.12)
# Requirement already satisfied: neo4j<6.0,>=4.4.12 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from graphdatascience->-r requirements.txt (line 2)) (5.24.0)
# Requirement already satisfied: textdistance<5.0,>=4.0 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from graphdatascience->-r requirements.txt (line 2)) (4.6.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from langchain>=0.0.216->-r requirements.txt (line 4)) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from langchain>=0.0.216->-r requirements.txt (line 4)) (2.0.35)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.0 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from langchain>=0.0.216->-r requirements.txt (line 4)) (0.3.2)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from langchain>=0.0.216->-r requirements.txt (line 4)) (0.3.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from langchain>=0.0.216->-r requirements.txt (line 4)) (0.1.125)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from langchain>=0.0.216->-r requirements.txt (line 4)) (2.9.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from pandas->-r requirements.txt (line 9)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from pandas->-r requirements.txt (line 9)) (2024.1)
# Requirement already satisfied: entrypoints in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from altair<5->-r requirements.txt (line 11)) (0.4)
# Requirement already satisfied: jinja2 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from altair<5->-r requirements.txt (line 11)) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from altair<5->-r requirements.txt (line 11)) (4.23.0)
# Requirement already satisfied: toolz in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from altair<5->-r requirements.txt (line 11)) (0.12.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai==0.28->-r requirements.txt (line 1)) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai==0.28->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai==0.28->-r requirements.txt (line 1)) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai==0.28->-r requirements.txt (line 1)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai==0.28->-r requirements.txt (line 1)) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai==0.28->-r requirements.txt (line 1)) (1.11.1)
# Requirement already satisfied: colorama in c:\users\akshi\appdata\roaming\python\python312\site-packages (from click<9,>=7.0->streamlit==1.23.1->-r requirements.txt (line 5)) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from gitpython!=3.1.19,<4,>=3->streamlit==1.23.1->-r requirements.txt (line 5)) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from importlib-metadata<7,>=1.4->streamlit==1.23.1->-r requirements.txt (line 5)) (3.20.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=3.0->altair<5->-r requirements.txt (line 11)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=3.0->altair<5->-r requirements.txt (line 11)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=3.0->altair<5->-r requirements.txt (line 11)) (0.20.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<0.4.0,>=0.3.0->langchain>=0.0.216->-r requirements.txt (line 4)) (1.33)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain>=0.0.216->-r requirements.txt (line 4)) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain>=0.0.216->-r requirements.txt (line 4)) (3.10.7)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain>=0.0.216->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain>=0.0.216->-r requirements.txt (line 4)) (2.23.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from jinja2->altair<5->-r requirements.txt (line 11)) (2.1.5)
# Requirement already satisfied: pywin32>=226 in c:\users\akshi\appdata\roaming\python\python312\site-packages (from pympler<2,>=0.9->streamlit==1.23.1->-r requirements.txt (line 5)) (306)
# Requirement already satisfied: six>=1.5 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil<3,>=2->streamlit==1.23.1->-r requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.20->openai==0.28->-r requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.20->openai==0.28->-r requirements.txt (line 1)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.20->openai==0.28->-r requirements.txt (line 1)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.20->openai==0.28->-r requirements.txt (line 1)) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from rich<14,>=10.11.0->streamlit==1.23.1->-r requirements.txt (line 5)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\akshi\appdata\roaming\python\python312\site-packages (from rich<14,>=10.11.0->streamlit==1.23.1->-r requirements.txt (line 5)) (2.18.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain>=0.0.216->-r requirements.txt (line 4)) (3.1.0)
# Requirement already satisfied: pytz-deprecation-shim in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from tzlocal<5,>=1.1->streamlit==1.23.1->-r requirements.txt (line 5)) (0.1.0.post0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3->streamlit==1.23.1->-r requirements.txt (line 5)) (5.0.1)
# Requirement already satisfied: anyio in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain>=0.0.216->-r requirements.txt (line 4)) (4.5.0)
# Requirement already satisfied: httpcore==1.* in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain>=0.0.216->-r requirements.txt (line 4)) (1.0.5)
# Requirement already satisfied: sniffio in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain>=0.0.216->-r requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain>=0.0.216->-r requirements.txt (line 4)) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.0->langchain>=0.0.216->-r requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\akshi\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.11.0->streamlit==1.23.1->-r requirements.txt (line 5)) (0.1.2)

# %%
import os
import openai
from string import Template
import json
from neo4j import GraphDatabase
import glob
from timeit import default_timer as timer
from dotenv import load_dotenv
from time import sleep

# import requests
# import time

# %% [markdown]
# ## Configurations

# %%
# Load environment variables
load_dotenv()
# Out:
# True

# %%
# OpenAI API configuration
# openai.api_type = "azure"
openai.api_key = os.getenv("OPENAI_API_KEY")
# openai.api_base = os.getenv("OPENAI_API_BASE")
# openai.api_version = os.getenv("OPENAI_API_VERSION")
openai_deployment = "gpt-4"

# Neo4j configuration & constraints
neo4j_url = os.getenv("NEO4J_CONNECTION_URL")
neo4j_user = os.getenv("NEO4J_USER")
neo4j_password = os.getenv("NEO4J_PASSWORD")
gds = GraphDatabase.driver(neo4j_url, auth=(neo4j_user, neo4j_password))

# %%
# Function to call the OpenAI API
def process_gpt(file_prompt, system_msg):
    completion = openai.ChatCompletion.create(
        model="gpt-4",
        max_tokens=3000,
        temperature=0,
        messages=[
            {"role": "system", "content": system_msg},
            {"role": "user", "content": file_prompt},
        ],
    )
    nlp_results = completion.choices[0].message.content
    sleep(8)
    return nlp_results


# Function to take folder of files and a prompt template, and return a json-object of all the entities and relationships
def extract_entities_relationships(folder, prompt_template):
    start = timer()
    files = glob.glob(f"./data/{folder}/*")
    system_msg = "You are a helpful IT-project and account management expert who extracts information from documents."
    print(f"Running pipeline for {len(files)} files in {folder} folder")
    results = []
    for i, file in enumerate(files):
        print(f"Extracting entities and relationships for {file}")
        try:
            with open(file, "r") as f:
                text = f.read().rstrip()
                prompt = Template(prompt_template).substitute(ctext=text)
                result = process_gpt(prompt, system_msg=system_msg)
                results.append(json.loads(result))
        except Exception as e:
            print(f"Error processing {file}: {e}")
    end = timer()
    print(f"Pipeline completed in {end-start} seconds")
    return results


# Function to take a json-object of entitites and relationships and generate cypher query for creating those entities
def generate_cypher(json_obj):
    e_statements = []
    r_statements = []

    e_label_map = {}

    # loop through our json object
    for i, obj in enumerate(json_obj):
        print(f"Generating cypher for file {i+1} of {len(json_obj)}")
        for entity in obj["entities"]:
            label = entity["label"]
            id = entity["id"]
            id = id.replace("-", "").replace("_", "")
            properties = {k: v for k, v in entity.items() if k not in ["label", "id"]}

            cypher = f'MERGE (n:{label} {{id: "{id}"}})'
            if properties:
                props_str = ", ".join(
                    [f'n.{key} = "{val}"' for key, val in properties.items()]
                )
                cypher += f" ON CREATE SET {props_str}"
            e_statements.append(cypher)
            e_label_map[id] = label

        for rs in obj["relationships"]:
            src_id, rs_type, tgt_id = rs.split("|")
            src_id = src_id.replace("-", "").replace("_", "")
            tgt_id = tgt_id.replace("-", "").replace("_", "")

            src_label = e_label_map[src_id]
            tgt_label = e_label_map[tgt_id]

            cypher = f'MERGE (a:{src_label} {{id: "{src_id}"}}) MERGE (b:{tgt_label} {{id: "{tgt_id}"}}) MERGE (a)-[:{rs_type}]->(b)'
            r_statements.append(cypher)

    with open("cyphers.txt", "w") as outfile:
        outfile.write("\n".join(e_statements + r_statements))

    return e_statements + r_statements


# Final function to bring all the steps together
def ingestion_pipeline(folders):
    # Extrating the entites and relationships from each folder, append into one json_object
    entities_relationships = []
    for key, value in folders.items():
        entities_relationships.extend(extract_entities_relationships(key, value))

    # Generate and execute cypher statements
    cypher_statements = generate_cypher(entities_relationships)
    for i, stmt in enumerate(cypher_statements):
        print(f"Executing cypher statement {i+1} of {len(cypher_statements)}")
        try:
            gds.execute_query(stmt)
        except Exception as e:
            with open("failed_statements.txt", "w") as f:
                f.write(f"{stmt} - Exception: {e}\n")

# %%
# Prompt for processing project briefs
project_prompt_template = """
From the Project Brief below, extract the following Entities & relationships described in the mentioned format 
0. ALWAYS FINISH THE OUTPUT. Never send partial responses
1. First, look for these Entity types in the text and generate as comma-separated format similar to entity type.
   `id` property of each entity must be alphanumeric and must be unique among the entities. You will be referring this property to define the relationship between entities. Do not create new entity types that aren't mentioned below. Document must be summarized and stored inside Project entity under `summary` property. You will have to generate as many entities as needed as per the types below:
    Entity Types:
    label:'Project',id:string,name:string;summary:string //Project mentioned in the brief; `id` property is the full name of the project, in lowercase, with no capital letters, special characters, spaces or hyphens; Contents of original document must be summarized inside 'summary' property
    label:'Technology',id:string,name:string //Technology Entity; `id` property is the name of the technology, in camel-case. Identify as many of the technologies used as possible
    label:'Client',id:string,name:string;industry:string //Client that the project was done for; `id` property is the name of the Client, in camel-case; 'industry' is the industry that the client operates in, as mentioned in the project brief.
    
2. Next generate each relationships as triples of head, relationship and tail. To refer the head and tail entity, use their respective `id` property. Relationship property should be mentioned within brackets as comma-separated. They should follow these relationship types below. You will have to generate as many relationships as needed as defined below:
    Relationship types:
    project|USES_TECH|technology 
    project|HAS_CLIENT|client


3. The output should look like :
{
    "entities": [{"label":"Project","id":string,"name":string,"summary":string}],
    "relationships": ["projectid|USES_TECH|technologyid"]
}

Case Sheet:
$ctext
"""


# Prompt for processing peoples' profiles
people_prompt_template = """From the list of people below, extract the following Entities & relationships described in the mentioned format 
0. ALWAYS FINISH THE OUTPUT. Never send partial responses
1. First, look for these Entity types in the text and generate as comma-separated format similar to entity type.
   `id` property of each entity must be alphanumeric and must be unique among the entities. You will be referring this property to define the relationship between entities. Do not create new entity types that aren't mentioned below. You will have to generate as many entities as needed as per the types below:
    Entity Types:
    label:'Person',id:string,name:string //Person that the data is about. `id` property is the name of the person, in camel-case. 'name' is the person's name, as spelled in the text.
    label:'Project',id:string,name:string;summary:string //Project mentioned in the profile; `id` property is the full lowercase name of the project, with no capital letters, special characters, spaces or hyphens.
    label:'Technology',id:string,name:string //Technology Entity, as listed in the "skills"-section of every person; `id` property is the name of the technology, in camel-case.
    
3. Next generate each relationships as triples of head, relationship and tail. To refer the head and tail entity, use their respective `id` property. Relationship property should be mentioned within brackets as comma-separated. They should follow these relationship types below. You will have to generate as many relationships as needed as defined below:
    Relationship types:
    person|HAS_SKILLS|technology 
    project|HAS_PEOPLE|person


The output should look like :
{
    "entities": [{"label":"Person","id":string,"name":string}],
    "relationships": ["projectid|HAS_PEOPLE|personid"]
}

Case Sheet:
$ctext
"""


# Prompt for processing slack messages

slack_prompt_template = """
From the list of messages below, extract the following Entities & relationships described in the mentioned format 
0. ALWAYS FINISH THE OUTPUT. Never send partial responses
1. First, look for these Entity types in the text and generate as comma-separated format similar to entity type.
   `id` property of each entity must be alphanumeric and must be unique among the entities. You will be referring this property to define the relationship between entities. Do not create new entity types that aren't mentioned below. You will have to generate as many entities as needed as per the types below:
    Entity Types:
    label:'Person',id:string,name:string //Person that sent the message. `id` property is the name of the person, in camel-case; for example, "michaelClark", or "emmaMartinez"; 'name' is the person's name, as spelled in the text.
    label:'SlackMessage',id:string,text:string //The Slack-Message that was sent; 'id' property should be the message id, as spelled in the reference. 'text' property is the text content of the message, as spelled in the reference
    
3. Next generate each relationships as triples of head, relationship and tail. To refer the head and tail entity, use their respective `id` property. Relationship property should be mentioned within brackets as comma-separated. They should follow these relationship types below. You will have to generate as many relationships as needed as defined below:
    Relationship types:
    personid|SENT|slackmessageid

The output should look like :
{
    "entities": [{"label":"SlackMessage","id":string,"text":string}],
    "relationships": ["personid|SENT|messageid"]
}

Case Sheet:
$ctext
"""

# %%
folders = {
    "people_profiles": people_prompt_template,
    "project_briefs": project_prompt_template,
    "slack_messages": slack_prompt_template,
}

ingestion_pipeline(folders)
# Out:
# Running pipeline for 3 files in people_profiles folder
# Extracting entities and relationships for ./data/people_profiles\people-profiles1.md
# Extracting entities and relationships for ./data/people_profiles\people-profiles2.md
# Extracting entities and relationships for ./data/people_profiles\people-profiles3.md
# Pipeline completed in 145.53107479999744 seconds
# Running pipeline for 11 files in project_briefs folder
# Extracting entities and relationships for ./data/project_briefs\AlphaCorp AWS-Powered Sales Analytics Dashboard.md
# Extracting entities and relationships for ./data/project_briefs\AlphaCorp Customer Support Chatbot.md
# Extracting entities and relationships for ./data/project_briefs\AlphaCorp Supply Chain Optimization Platform.md
# Extracting entities and relationships for ./data/project_briefs\BetaHealth AI-Driven Patient Care Enhancement Platform on Azure.md
# Extracting entities and relationships for ./data/project_briefs\BetaHealth Secure Healthcare Data Analytics Platform on Azure.md
# Extracting entities and relationships for ./data/project_briefs\BetaHealth Telemedicine Platform on Microsoft Azure.md
# Extracting entities and relationships for ./data/project_briefs\DeltaEdu AI-Powered Student Performance Analytics on AWS.md
# Extracting entities and relationships for ./data/project_briefs\DeltaEdu Virtual Classroom Platform on AWS.md
# Extracting entities and relationships for ./data/project_briefs\EpsilonFinance Mobile-First Digital Wallet on Google Cloud.md
# Extracting entities and relationships for ./data/project_briefs\GammaTech Autonomous Fleet Management System on Azure.md
# Extracting entities and relationships for ./data/project_briefs\GammaTech Smart Logistics Platform on Azure.md
# Pipeline completed in 420.1317271000007 seconds
# Running pipeline for 7 files in slack_messages folder
# Extracting entities and relationships for ./data/slack_messages\slack_messages1.json
# Extracting entities and relationships for ./data/slack_messages\slack_messages2.json
# Extracting entities and relationships for ./data/slack_messages\slack_messages3.json
# Extracting entities and relationships for ./data/slack_messages\slack_messages4.json
# Extracting entities and relationships for ./data/slack_messages\slack_messages5.json
# Extracting entities and relationships for ./data/slack_messages\slack_messages6.json
# Extracting entities and relationships for ./data/slack_messages\slack_messages7.json
# Pipeline completed in 167.26494829999865 seconds
# Generating cypher for file 1 of 21
# Generating cypher for file 2 of 21
# Generating cypher for file 3 of 21
# Generating cypher for file 4 of 21
# Generating cypher for file 5 of 21
# Generating cypher for file 6 of 21
# Generating cypher for file 7 of 21
# Generating cypher for file 8 of 21
# Generating cypher for file 9 of 21
# Generating cypher for file 10 of 21
# Generating cypher for file 11 of 21
# Generating cypher for file 12 of 21
# Generating cypher for file 13 of 21
# Generating cypher for file 14 of 21
# Generating cypher for file 15 of 21
# Generating cypher for file 16 of 21
# Generating cypher for file 17 of 21
# Generating cypher for file 18 of 21
# Generating cypher for file 19 of 21
# Generating cypher for file 20 of 21
# Generating cypher for file 21 of 21
# Executing cypher statement 1 of 466
# Executing cypher statement 2 of 466
# Executing cypher statement 3 of 466
# Executing cypher statement 4 of 466
# Executing cypher statement 5 of 466
# Executing cypher statement 6 of 466
# Executing cypher statement 7 of 466
# Executing cypher statement 8 of 466
# Executing cypher statement 9 of 466
# Executing cypher statement 10 of 466
# Executing cypher statement 11 of 466
# Executing cypher statement 12 of 466
# Executing cypher statement 13 of 466
# Executing cypher statement 14 of 466
# Executing cypher statement 15 of 466
# Executing cypher statement 16 of 466
# Executing cypher statement 17 of 466
# Executing cypher statement 18 of 466
# Executing cypher statement 19 of 466
# Executing cypher statement 20 of 466
# Executing cypher statement 21 of 466
# Executing cypher statement 22 of 466
# Executing cypher statement 23 of 466
# Executing cypher statement 24 of 466
# Executing cypher statement 25 of 466
# Executing cypher statement 26 of 466
# Executing cypher statement 27 of 466
# Executing cypher statement 28 of 466
# Executing cypher statement 29 of 466
# Executing cypher statement 30 of 466
# Executing cypher statement 31 of 466
# Executing cypher statement 32 of 466
# Executing cypher statement 33 of 466
# Executing cypher statement 34 of 466
# Executing cypher statement 35 of 466
# Executing cypher statement 36 of 466
# Executing cypher statement 37 of 466
# Executing cypher statement 38 of 466
# Executing cypher statement 39 of 466
# Executing cypher statement 40 of 466
# Executing cypher statement 41 of 466
# Executing cypher statement 42 of 466
# Executing cypher statement 43 of 466
# Executing cypher statement 44 of 466
# Executing cypher statement 45 of 466
# Executing cypher statement 46 of 466
# Executing cypher statement 47 of 466
# Executing cypher statement 48 of 466
# Executing cypher statement 49 of 466
# Executing cypher statement 50 of 466
# Executing cypher statement 51 of 466
# Executing cypher statement 52 of 466
# Executing cypher statement 53 of 466
# Executing cypher statement 54 of 466
# Executing cypher statement 55 of 466
# Executing cypher statement 56 of 466
# Executing cypher statement 57 of 466
# Executing cypher statement 58 of 466
# Executing cypher statement 59 of 466
# Executing cypher statement 60 of 466
# Executing cypher statement 61 of 466
# Executing cypher statement 62 of 466
# Executing cypher statement 63 of 466
# Executing cypher statement 64 of 466
# Executing cypher statement 65 of 466
# Executing cypher statement 66 of 466
# Executing cypher statement 67 of 466
# Executing cypher statement 68 of 466
# Executing cypher statement 69 of 466
# Executing cypher statement 70 of 466
# Executing cypher statement 71 of 466
# Executing cypher statement 72 of 466
# Executing cypher statement 73 of 466
# Executing cypher statement 74 of 466
# Executing cypher statement 75 of 466
# Executing cypher statement 76 of 466
# Executing cypher statement 77 of 466
# Executing cypher statement 78 of 466
# Executing cypher statement 79 of 466
# Executing cypher statement 80 of 466
# Executing cypher statement 81 of 466
# Executing cypher statement 82 of 466
# Executing cypher statement 83 of 466
# Executing cypher statement 84 of 466
# Executing cypher statement 85 of 466
# Executing cypher statement 86 of 466
# Executing cypher statement 87 of 466
# Executing cypher statement 88 of 466
# Executing cypher statement 89 of 466
# Executing cypher statement 90 of 466
# Executing cypher statement 91 of 466
# Executing cypher statement 92 of 466
# Executing cypher statement 93 of 466
# Executing cypher statement 94 of 466
# Executing cypher statement 95 of 466
# Executing cypher statement 96 of 466
# Executing cypher statement 97 of 466
# Executing cypher statement 98 of 466
# Executing cypher statement 99 of 466
# Executing cypher statement 100 of 466
# Executing cypher statement 101 of 466
# Executing cypher statement 102 of 466
# Executing cypher statement 103 of 466
# Executing cypher statement 104 of 466
# Executing cypher statement 105 of 466
# Executing cypher statement 106 of 466
# Executing cypher statement 107 of 466
# Executing cypher statement 108 of 466
# Executing cypher statement 109 of 466
# Executing cypher statement 110 of 466
# Executing cypher statement 111 of 466
# Executing cypher statement 112 of 466
# Executing cypher statement 113 of 466
# Executing cypher statement 114 of 466
# Executing cypher statement 115 of 466
# Executing cypher statement 116 of 466
# Executing cypher statement 117 of 466
# Executing cypher statement 118 of 466
# Executing cypher statement 119 of 466
# Executing cypher statement 120 of 466
# Executing cypher statement 121 of 466
# Executing cypher statement 122 of 466
# Executing cypher statement 123 of 466
# Executing cypher statement 124 of 466
# Executing cypher statement 125 of 466
# Executing cypher statement 126 of 466
# Executing cypher statement 127 of 466
# Executing cypher statement 128 of 466
# Executing cypher statement 129 of 466
# Executing cypher statement 130 of 466
# Executing cypher statement 131 of 466
# Executing cypher statement 132 of 466
# Executing cypher statement 133 of 466
# Executing cypher statement 134 of 466
# Executing cypher statement 135 of 466
# Executing cypher statement 136 of 466
# Executing cypher statement 137 of 466
# Executing cypher statement 138 of 466
# Executing cypher statement 139 of 466
# Executing cypher statement 140 of 466
# Executing cypher statement 141 of 466
# Executing cypher statement 142 of 466
# Executing cypher statement 143 of 466
# Executing cypher statement 144 of 466
# Executing cypher statement 145 of 466
# Executing cypher statement 146 of 466
# Executing cypher statement 147 of 466
# Executing cypher statement 148 of 466
# Executing cypher statement 149 of 466
# Executing cypher statement 150 of 466
# Executing cypher statement 151 of 466
# Executing cypher statement 152 of 466
# Executing cypher statement 153 of 466
# Executing cypher statement 154 of 466
# Executing cypher statement 155 of 466
# Executing cypher statement 156 of 466
# Executing cypher statement 157 of 466
# Executing cypher statement 158 of 466
# Executing cypher statement 159 of 466
# Executing cypher statement 160 of 466
# Executing cypher statement 161 of 466
# Executing cypher statement 162 of 466
# Executing cypher statement 163 of 466
# Executing cypher statement 164 of 466
# Executing cypher statement 165 of 466
# Executing cypher statement 166 of 466
# Executing cypher statement 167 of 466
# Executing cypher statement 168 of 466
# Executing cypher statement 169 of 466
# Executing cypher statement 170 of 466
# Executing cypher statement 171 of 466
# Executing cypher statement 172 of 466
# Executing cypher statement 173 of 466
# Executing cypher statement 174 of 466
# Executing cypher statement 175 of 466
# Executing cypher statement 176 of 466
# Executing cypher statement 177 of 466
# Executing cypher statement 178 of 466
# Executing cypher statement 179 of 466
# Executing cypher statement 180 of 466
# Executing cypher statement 181 of 466
# Executing cypher statement 182 of 466
# Executing cypher statement 183 of 466
# Executing cypher statement 184 of 466
# Executing cypher statement 185 of 466
# Executing cypher statement 186 of 466
# Executing cypher statement 187 of 466
# Executing cypher statement 188 of 466
# Executing cypher statement 189 of 466
# Executing cypher statement 190 of 466
# Executing cypher statement 191 of 466
# Executing cypher statement 192 of 466
# Executing cypher statement 193 of 466
# Executing cypher statement 194 of 466
# Executing cypher statement 195 of 466
# Executing cypher statement 196 of 466
# Executing cypher statement 197 of 466
# Executing cypher statement 198 of 466
# Executing cypher statement 199 of 466
# Executing cypher statement 200 of 466
# Executing cypher statement 201 of 466
# Executing cypher statement 202 of 466
# Executing cypher statement 203 of 466
# Executing cypher statement 204 of 466
# Executing cypher statement 205 of 466
# Executing cypher statement 206 of 466
# Executing cypher statement 207 of 466
# Executing cypher statement 208 of 466
# Executing cypher statement 209 of 466
# Executing cypher statement 210 of 466
# Executing cypher statement 211 of 466
# Executing cypher statement 212 of 466
# Executing cypher statement 213 of 466
# Executing cypher statement 214 of 466
# Executing cypher statement 215 of 466
# Executing cypher statement 216 of 466
# Executing cypher statement 217 of 466
# Executing cypher statement 218 of 466
# Executing cypher statement 219 of 466
# Executing cypher statement 220 of 466
# Executing cypher statement 221 of 466
# Executing cypher statement 222 of 466
# Executing cypher statement 223 of 466
# Executing cypher statement 224 of 466
# Executing cypher statement 225 of 466
# Executing cypher statement 226 of 466
# Executing cypher statement 227 of 466
# Executing cypher statement 228 of 466
# Executing cypher statement 229 of 466
# Executing cypher statement 230 of 466
# Executing cypher statement 231 of 466
# Executing cypher statement 232 of 466
# Executing cypher statement 233 of 466
# Executing cypher statement 234 of 466
# Executing cypher statement 235 of 466
# Executing cypher statement 236 of 466
# Executing cypher statement 237 of 466
# Executing cypher statement 238 of 466
# Executing cypher statement 239 of 466
# Executing cypher statement 240 of 466
# Executing cypher statement 241 of 466
# Executing cypher statement 242 of 466
# Executing cypher statement 243 of 466
# Executing cypher statement 244 of 466
# Executing cypher statement 245 of 466
# Executing cypher statement 246 of 466
# Executing cypher statement 247 of 466
# Executing cypher statement 248 of 466
# Executing cypher statement 249 of 466
# Executing cypher statement 250 of 466
# Executing cypher statement 251 of 466
# Executing cypher statement 252 of 466
# Executing cypher statement 253 of 466
# Executing cypher statement 254 of 466
# Executing cypher statement 255 of 466
# Executing cypher statement 256 of 466
# Executing cypher statement 257 of 466
# Executing cypher statement 258 of 466
# Executing cypher statement 259 of 466
# Executing cypher statement 260 of 466
# Executing cypher statement 261 of 466
# Executing cypher statement 262 of 466
# Executing cypher statement 263 of 466
# Executing cypher statement 264 of 466
# Executing cypher statement 265 of 466
# Executing cypher statement 266 of 466
# Executing cypher statement 267 of 466
# Executing cypher statement 268 of 466
# Executing cypher statement 269 of 466
# Executing cypher statement 270 of 466
# Executing cypher statement 271 of 466
# Executing cypher statement 272 of 466
# Executing cypher statement 273 of 466
# Executing cypher statement 274 of 466
# Executing cypher statement 275 of 466
# Executing cypher statement 276 of 466
# Executing cypher statement 277 of 466
# Executing cypher statement 278 of 466
# Executing cypher statement 279 of 466
# Executing cypher statement 280 of 466
# Executing cypher statement 281 of 466
# Executing cypher statement 282 of 466
# Executing cypher statement 283 of 466
# Executing cypher statement 284 of 466
# Executing cypher statement 285 of 466
# Executing cypher statement 286 of 466
# Executing cypher statement 287 of 466
# Executing cypher statement 288 of 466
# Executing cypher statement 289 of 466
# Executing cypher statement 290 of 466
# Executing cypher statement 291 of 466
# Executing cypher statement 292 of 466
# Executing cypher statement 293 of 466
# Executing cypher statement 294 of 466
# Executing cypher statement 295 of 466
# Executing cypher statement 296 of 466
# Executing cypher statement 297 of 466
# Executing cypher statement 298 of 466
# Executing cypher statement 299 of 466
# Executing cypher statement 300 of 466
# Executing cypher statement 301 of 466
# Executing cypher statement 302 of 466
# Executing cypher statement 303 of 466
# Executing cypher statement 304 of 466
# Executing cypher statement 305 of 466
# Executing cypher statement 306 of 466
# Executing cypher statement 307 of 466
# Executing cypher statement 308 of 466
# Executing cypher statement 309 of 466
# Executing cypher statement 310 of 466
# Executing cypher statement 311 of 466
# Executing cypher statement 312 of 466
# Executing cypher statement 313 of 466
# Executing cypher statement 314 of 466
# Executing cypher statement 315 of 466
# Executing cypher statement 316 of 466
# Executing cypher statement 317 of 466
# Executing cypher statement 318 of 466
# Executing cypher statement 319 of 466
# Executing cypher statement 320 of 466
# Executing cypher statement 321 of 466
# Executing cypher statement 322 of 466
# Executing cypher statement 323 of 466
# Executing cypher statement 324 of 466
# Executing cypher statement 325 of 466
# Executing cypher statement 326 of 466
# Executing cypher statement 327 of 466
# Executing cypher statement 328 of 466
# Executing cypher statement 329 of 466
# Executing cypher statement 330 of 466
# Executing cypher statement 331 of 466
# Executing cypher statement 332 of 466
# Executing cypher statement 333 of 466
# Executing cypher statement 334 of 466
# Executing cypher statement 335 of 466
# Executing cypher statement 336 of 466
# Executing cypher statement 337 of 466
# Executing cypher statement 338 of 466
# Executing cypher statement 339 of 466
# Executing cypher statement 340 of 466
# Executing cypher statement 341 of 466
# Executing cypher statement 342 of 466
# Executing cypher statement 343 of 466
# Executing cypher statement 344 of 466
# Executing cypher statement 345 of 466
# Executing cypher statement 346 of 466
# Executing cypher statement 347 of 466
# Executing cypher statement 348 of 466
# Executing cypher statement 349 of 466
# Executing cypher statement 350 of 466
# Executing cypher statement 351 of 466
# Executing cypher statement 352 of 466
# Executing cypher statement 353 of 466
# Executing cypher statement 354 of 466
# Executing cypher statement 355 of 466
# Executing cypher statement 356 of 466
# Executing cypher statement 357 of 466
# Executing cypher statement 358 of 466
# Executing cypher statement 359 of 466
# Executing cypher statement 360 of 466
# Executing cypher statement 361 of 466
# Executing cypher statement 362 of 466
# Executing cypher statement 363 of 466
# Executing cypher statement 364 of 466
# Executing cypher statement 365 of 466
# Executing cypher statement 366 of 466
# Executing cypher statement 367 of 466
# Executing cypher statement 368 of 466
# Executing cypher statement 369 of 466
# Executing cypher statement 370 of 466
# Executing cypher statement 371 of 466
# Executing cypher statement 372 of 466
# Executing cypher statement 373 of 466
# Executing cypher statement 374 of 466
# Executing cypher statement 375 of 466
# Executing cypher statement 376 of 466
# Executing cypher statement 377 of 466
# Executing cypher statement 378 of 466
# Executing cypher statement 379 of 466
# Executing cypher statement 380 of 466
# Executing cypher statement 381 of 466
# Executing cypher statement 382 of 466
# Executing cypher statement 383 of 466
# Executing cypher statement 384 of 466
# Executing cypher statement 385 of 466
# Executing cypher statement 386 of 466
# Executing cypher statement 387 of 466
# Executing cypher statement 388 of 466
# Executing cypher statement 389 of 466
# Executing cypher statement 390 of 466
# Executing cypher statement 391 of 466
# Executing cypher statement 392 of 466
# Executing cypher statement 393 of 466
# Executing cypher statement 394 of 466
# Executing cypher statement 395 of 466
# Executing cypher statement 396 of 466
# Executing cypher statement 397 of 466
# Executing cypher statement 398 of 466
# Executing cypher statement 399 of 466
# Executing cypher statement 400 of 466
# Executing cypher statement 401 of 466
# Executing cypher statement 402 of 466
# Executing cypher statement 403 of 466
# Executing cypher statement 404 of 466
# Executing cypher statement 405 of 466
# Executing cypher statement 406 of 466
# Executing cypher statement 407 of 466
# Executing cypher statement 408 of 466
# Executing cypher statement 409 of 466
# Executing cypher statement 410 of 466
# Executing cypher statement 411 of 466
# Executing cypher statement 412 of 466
# Executing cypher statement 413 of 466
# Executing cypher statement 414 of 466
# Executing cypher statement 415 of 466
# Executing cypher statement 416 of 466
# Executing cypher statement 417 of 466
# Executing cypher statement 418 of 466
# Executing cypher statement 419 of 466
# Executing cypher statement 420 of 466
# Executing cypher statement 421 of 466
# Executing cypher statement 422 of 466
# Executing cypher statement 423 of 466
# Executing cypher statement 424 of 466
# Executing cypher statement 425 of 466
# Executing cypher statement 426 of 466
# Executing cypher statement 427 of 466
# Executing cypher statement 428 of 466
# Executing cypher statement 429 of 466
# Executing cypher statement 430 of 466
# Executing cypher statement 431 of 466
# Executing cypher statement 432 of 466
# Executing cypher statement 433 of 466
# Executing cypher statement 434 of 466
# Executing cypher statement 435 of 466
# Executing cypher statement 436 of 466
# Executing cypher statement 437 of 466
# Executing cypher statement 438 of 466
# Executing cypher statement 439 of 466
# Executing cypher statement 440 of 466
# Executing cypher statement 441 of 466
# Executing cypher statement 442 of 466
# Executing cypher statement 443 of 466
# Executing cypher statement 444 of 466
# Executing cypher statement 445 of 466
# Executing cypher statement 446 of 466
# Executing cypher statement 447 of 466
# Executing cypher statement 448 of 466
# Executing cypher statement 449 of 466
# Executing cypher statement 450 of 466
# Executing cypher statement 451 of 466
# Executing cypher statement 452 of 466
# Executing cypher statement 453 of 466
# Executing cypher statement 454 of 466
# Executing cypher statement 455 of 466
# Executing cypher statement 456 of 466
# Executing cypher statement 457 of 466
# Executing cypher statement 458 of 466
# Executing cypher statement 459 of 466
# Executing cypher statement 460 of 466
# Executing cypher statement 461 of 466
# Executing cypher statement 462 of 466
# Executing cypher statement 463 of 466
# Executing cypher statement 464 of 466
# Executing cypher statement 465 of 466
# Executing cypher statement 466 of 466
